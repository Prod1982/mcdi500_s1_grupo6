# %% [markdown]
# MCDI500 – Fase 1: Definición del Proyecto
# Título
#
# Impacto de la Inteligencia Artificial en el empleo, la productividad y la capacitación laboral
#
# Integrantes:
#
# Pablo Rodríguez
# Luiskar Espinoza

# %% [markdown]
# Problemática
#
# El avance de la inteligencia artificial está generando cambios en el mercado laboral, afectando la automatización de tareas, la productividad y las necesidades de capacitación. En este proyecto se analizará un conjunto de datos relacionado con estos factores para identificar patrones y apoyar la comprensión de su impacto.
#
# Objetivo general
# Analizar el conjunto de datos sobre el impacto de la inteligencia artificial en el ámbito laboral mediante herramientas de ciencia de datos y un flujo de trabajo reproducible.
#
# Objetivos específicos
# Configurar un entorno de trabajo reproducible utilizando Git, GitHub y Jupyter Notebook.
# Cargar y explorar preliminarmente el conjunto de datos.
# Planificar las etapas de limpieza, transformación y análisis que se desarrollarán en las siguientes fases.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Entorno configurado correctamente.")

# %%
df = pd.read_csv("../data/ai_job_impact.csv")
print("Dataset cargado correctamente.")
print(df.shape)

# %% [markdown]
# Conclusión
#
# En esta primera fase se configuró el entorno de trabajo reproducible, se verificó la correcta carga del conjunto de datos y se estableció la base técnica para las siguientes etapas del proyecto, manteniendo coherencia con el repositorio GitHub y la planificación definida en el mapa conceptual.
